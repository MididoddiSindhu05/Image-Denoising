# %% [markdown]
# <a href="https://colab.research.google.com/github/MididoddiSindhu05/Image-Denoising/blob/main/Image1hdr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#Parse the .hdr metadata file
hdr_path = '/content/band1_image1.rad.hdr'

header_info = {}
with open(hdr_path, 'r') as f:
    for line in f:
        if '=' in line:
            key, value = line.strip().split('=')
            header_info[key.strip().lower()] = value.strip()
#Extract dimensions from header
width = int(header_info['samples'])
height = int(header_info['lines'])

#Read the binary .rad file as uint16
rad_path = '/content/band1_image1.rad'
image_data = np.fromfile(rad_path, dtype=np.uint16)

#Reshape to 2D image
image = image_data.reshape((height, width))

# Normalize to 8-bit for proper grayscale display
image_8bit = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)

# Display using matplotlib
plt.figure(figsize=(8, 6))
plt.imshow(image_8bit, cmap='gray')
plt.title('RAD Image Visualization')
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Bilateral Filtering
denoised = cv2.bilateralFilter(image_8bit, d=9, sigmaColor=75, sigmaSpace=75)

plt.figure(figsize=(8, 6))
plt.imshow(denoised, cmap='gray')
plt.title('Denoised Image (Bilateral Filter)')
plt.axis('off')
plt.show()
